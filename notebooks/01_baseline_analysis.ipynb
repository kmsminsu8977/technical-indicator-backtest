# %% [markdown]
# # Technical Indicator Backtest Baseline\n\n합성 샘플 데이터로 baseline 계산을 실행하는 최소 노트북입니다.\n

# %%
from pathlib import Path\nimport sys\n\nROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\nsys.path.insert(0, str(ROOT))\n\nfrom src.technical_backtest_baseline import run_baseline\n\nresults = run_baseline()\nresults[:3]\n
